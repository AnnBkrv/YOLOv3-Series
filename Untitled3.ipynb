# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnBkrv/YOLOv3-Series/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.chdir("drive/My Drive/Colab Notebooks/darknet")
# !pwd
# !chmod 755 darknet # gives me permission to run files in google drive
#!cp /content/gdrive/My\ Drive/Colab\ Notebooks/<FILE> /usr/local/bin
#!chmod 755 /usr/local/bin/<FILE>
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-29386d55744e> in <module>()
#       1 import os
# ----> 2 os.chdir("drive/My Drive/Colab Notebooks/darknet")
#       3 get_ipython().system('pwd')
#       4 get_ipython().system('chmod 755 darknet # gives me permission to run files in google drive')
#       5 #!cp /content/gdrive/My\ Drive/Colab\ Notebooks/<FILE> /usr/local/bin
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/My Drive/Colab Notebooks/darknet'

# %%
cd ..
# Out:
# /content/drive/My Drive/Colab Notebooks/darknet

# %%
#!mkdir build-release
# %cd "/content/drive/My Drive/Colab Notebooks/darknet/build-release"
# !pwd
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d96e7657069f> in <module>()
#       1 #!mkdir build-release
# ----> 2 os.chdir("build-release")
#       3 get_ipython().system('pwd')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'build-release'

# %%
import cv2 # computer vision library
import matplotlib.pyplot as plt
import os.path

fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')
# gets rid of the axes and ticks on the side of the image

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights photos/IMG_0439.jpg -dont_show --display 0

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
# changing the name of a file in bash while inserting a predefined variable into the new name
# i = 3
#!mv 'predictions.jpg' "prediction{i}.jpg"

# %%
imgs = os.listdir("photos")

# %%
# changing the file's contents from the command line
# !sed -i 's/CUDNN=1/CUDNN=0/g' Makefile # change the darknet makefile file to use gpu rather than the cpu
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile # stop the darknet from using opencv
# !make # i updated the makefile outside of the colab and now want the local darknet to compile according to that file

# %%
#!./darknet detect cfg/yolov3.cfg yolov3.weights photos/bali_traffic.mp4 -out_filename result.avi
#!./darknet detector demo data/coco.data cfg/yolov3.cfg yolov3.weights -dont_show data/dog.jpg -out_filename predict.jpg
# !./darknet detector test data/coco.data cfg/yolov3.cfg yolov3.weights photos/bali_traffic.mp4 -dont_show -i --display 0 -out_filename result.mp4
#!./darknet detector demo cfg/coco.data cfg/yolov3.cfg yolov3.weights photos/bali_traffic.mp4 -out_filename results.mp4
#!ssh -X -i @
# Out:
# Demo
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...

# %%
cap = cv2.VideoCapture('photos/bali_traffic.mp4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c3b7f3db9c15> in <module>()
# ----> 1 cap = cv2.VideoCapture('photos/bali_traffic.mp4')
#
# NameError: name 'cv2' is not defined

# %%
#!wget https://raw.githubusercontent.com/pjreddie/darknet/master/cfg/coco.data
# loading a file using bash from github (get the link by viewing the raw file)
# Out:
# --2020-08-18 15:29:04--  https://raw.githubusercontent.com/pjreddie/darknet/master/cfg/coco.data
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 183 [text/plain]
# Saving to: ‘coco.data.1’
#
# coco.data.1         100%[===================>]     183  --.-KB/s    in 0s
#
# 2020-08-18 15:29:04 (8.87 MB/s) - ‘coco.data.1’ saved [183/183]

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.1.2
