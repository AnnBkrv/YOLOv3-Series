# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnBkrv/YOLOv3-Series/blob/master/darknet_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# set directories, whatever

# !./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg
# run the darknet. use the yolov3 configuration in the cfg folder, 
# use yolov3 weights and run it on the dog image in the data folder


# plotting the prediction image using openCV.
# so what does opencv do? i can't print the image just with like print image or smth?
# that's all this library does?
import cv2 # computer vision library
import matplotlib.pyplot as plt
import os.path

fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')
# gets rid of the axes and ticks on the side of the image

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
import os
os.chdir("drive/My Drive/Colab Notebooks/darknet")
# !pwd
# !chmod 755 darknet # gives me permission to run files in google drive
#!cp /content/gdrive/My\ Drive/Colab\ Notebooks/<FILE> /usr/local/bin
#!chmod 755 /usr/local/bin/<FILE>
# Out:
# /content/drive/My Drive/Colab Notebooks/darknet

# %%
import cv2 # computer vision library
import matplotlib.pyplot as plt
import os.path

fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')
# gets rid of the axes and ticks on the side of the image

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights photos/IMG_0439.jpg

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights photos/IMG_9082.jpg

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights photos/trafalgar.jpg

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights photos/IMG_4113.jpg
# permission denied
# choose the gpu accelerator in runtime - change runtime type
# doesn't load. neither this nor the custom photos
# it does. wait

# %%
import os

path='photos'



imgList=os.listdir('photos')

print(imgList)

textFile=open('train.txt','w')


for img in imgList:
    imgPath=path+ img +'\n'
    textFile.write(imgPath)

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights photos/IMG_4113.jpg

# %%
#!mv 'predictions.jpg' "prediction1.jpg" # renames the file completely

# %%
i = 3
#!mv 'predictions.jpg' "prediction{i}.jpg"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-7d2fb4bd99c0> in <module>()
#       1 i = 3
#       2 #!mv 'predictions.jpg' "prediction{i}.jpg"
# ----> 3 textFile[1]
#
# TypeError: '_io.TextIOWrapper' object is not subscriptable

# %%
imgs = os.listdir("photos")

# %%
inp = "photos/" + imgs[0]
print(inp)
# Out:
# photos/IMG_9082.jpg

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights "photos/"+imgs[0]
# none of this works. maybe i could write a bash script. but then again, i don't need to do this shit
# plus i'm not gonna continue to use darknet anyway. so like eff it.
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `./darknet detect cfg/yolov3.cfg yolov3.weights as.string("photos/",imgs[0])'
