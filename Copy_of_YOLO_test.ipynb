# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnBkrv/YOLOv3-Series/blob/master/Copy_of_YOLO_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pjreddie/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5913, done.
# remote: Total 5913 (delta 0), reused 0 (delta 0), pack-reused 5913
# Receiving objects: 100% (5913/5913), 6.34 MiB | 32.28 MiB/s, done.
# Resolving deltas: 100% (3922/3922), done.

# %%
# !wget https://raw.githubusercontent.com/pjreddie/darknet/master/cfg/coco.data
# !ls
# Out:
# --2020-08-18 15:23:57--  https://raw.githubusercontent.com/pjreddie/darknet/master/cfg/coco.data
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 183 [text/plain]
# Saving to: ‘coco.data’
#
# coco.data           100%[===================>]     183  --.-KB/s    in 0s
#
# 2020-08-18 15:23:57 (13.4 MB/s) - ‘coco.data’ saved [183/183]
#
# coco.data  darknet  sample_data

# %%
import os
os.chdir("darknet")
# !pwd
# Out:
# /content/darknet

# %%
# !sed -i 's/GPU=0/GPU=1/g' Makefile # change the darknet makefile to use gpu rather than the cpu

# %%
# !make

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights # downloads the yolov3 weights into the current wd. some linux command

# %%
# !pip install opencv-python

# %%
# !pip list

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg
# run the darknet. use the yolov3 configuration in the cfg folder, 
# use yolov3 weights and run it on the dog image in the data folder

# %%
import cv2 # computer vision library
import matplotlib.pyplot as plt
import os.path

fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')
# gets rid of the axes and ticks on the side of the image

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip list

# %%
# !cat /etc/os-release
# Out:
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %%
# !ls /usr/local
# Out:
# bin	   cuda-10.1  _gcs_config_ops.so  LICENSE.txt  setup.cfg  xgboost
# cuda	   etc	      include		  man	       share
# cuda-10.0  games      lib		  sbin	       src

# %%
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/giraffe.jpg

# %%
import cv2 # computer vision library
import matplotlib.pyplot as plt
import os.path

fig,ax = plt.subplots()
ax.tick_params(labelbottom="off",bottom="off")
ax.tick_params(labelleft="off",left="off")
ax.set_xticklabels([]) 
ax.axis('off')
# gets rid of the axes and ticks on the side of the image

file = './predictions.jpg'
if os.path.exists(file):
  img = cv2.imread(file)
  show_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
  plt.imshow(show_img)
